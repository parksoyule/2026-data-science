# %% [markdown]
# <a href="https://colab.research.google.com/github/parksoyule/2026-data-science/blob/main/%EB%B0%95%EC%86%8C%EC%9C%A8_1%EC%A3%BC%EC%B0%A8_%EA%B9%83%ED%97%88%EB%B8%8C_%EC%A0%80%EC%9E%A5%EC%86%8C%ED%99%9C%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")
hello = list("Hello World")
num = len(hello)
for i in range(num):
  print(hello[i])
# Out:
# hello world!
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
user = int(input())

def kookoo(user):
  for i in range(1,10):
    answer = user * i
    print(answer)
  return
kookoo(user)
# Out:
# 3
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
